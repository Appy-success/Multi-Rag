# %%
# %pip install azure-ai-projects azure-search-documents azure-identity python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-ai-projects in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (2.0.0b1)
# Requirement already satisfied: azure-search-documents in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (11.6.0)
# Requirement already satisfied: azure-identity in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (1.20.0)
# Requirement already satisfied: python-dotenv in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (1.1.1)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-ai-projects) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-ai-projects) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-ai-projects) (12.27.1)
# Requirement already satisfied: azure-common>=1.1 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-search-documents) (1.1.28)
# Requirement already satisfied: cryptography>=2.5 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-identity) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-identity) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from azure-core>=1.35.0->azure-ai-projects) (2.32.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (2025.1.31)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pywin32>=226 in c:\users\aprajawat\appdata\roaming\python\python313\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity) (311)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pathlib import Path
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchIndex,
    SearchField,
    SearchFieldDataType,
    SimpleField,
    SearchableField,
    VectorSearch,
    HnswAlgorithmConfiguration,
    VectorSearchProfile,
)
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv
from openai import AzureOpenAI

print("📂 Loading environment variables...")

# Load .env from parent directory (up 2 levels)
notebook_dir = Path.cwd()
env_path = notebook_dir.parent.parent / '.env'

if env_path.exists():
    print(f"✅ Found .env at {env_path}")
    load_dotenv(env_path, override=True)
else:
    print(f"⚠️ .env not found at {env_path}, using current directory")
    load_dotenv()

# Load configuration
search_endpoint = os.getenv("SEARCH_ENDPOINT", "").strip()
search_key = os.getenv("SEARCH_KEY", "").strip()
openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT", "").strip()
openai_key = os.getenv("AZURE_OPENAI_API_KEY", "").strip()

print("\n📋 Configuration loaded:")
print(f"  Search Endpoint: {search_endpoint[:60] if search_endpoint else 'NOT SET'}...")
print(f"  Search Key: {'Set' if search_key else 'NOT SET'}")
print(f"  OpenAI Endpoint: {openai_endpoint[:60] if openai_endpoint else 'NOT SET'}...")
print(f"  OpenAI Key: {'Set' if openai_key else 'NOT SET'}")

if not all([search_endpoint, search_key, openai_endpoint, openai_key]):
    raise ValueError("❌ Missing required environment variables. Check your .env file.")

index_name = "contoso-manuals-index"
path_to_data = "./manuals"

print(f"\n📊 Index Configuration:")
print(f"  Index Name: {index_name}")
print(f"  Data Path: {path_to_data}")
# Out:
# 📂 Loading environment variables...
# ✅ Found .env at c:\Azure-Deleveries\AI-3016-ENU-PowerPoint\RAG-Live-demo\rag-app\python\.env
#
# 📋 Configuration loaded:
#   Search Endpoint: https://apsearchfoundary123.search.windows.net/...
#   Search Key: Set
#   OpenAI Endpoint: https://aphubaiservices.openai.azure.com/...
#   OpenAI Key: Set
#
# 📊 Index Configuration:
#   Index Name: contoso-manuals-index
#   Data Path: ./manuals

# %%
# Initialize Azure Search client
print(f"🔍 Connecting to Azure Search at: {search_endpoint}")

search_credential = AzureKeyCredential(search_key)
search_index_client = SearchIndexClient(endpoint=search_endpoint, credential=search_credential)
search_client = SearchClient(endpoint=search_endpoint, index_name=index_name, credential=search_credential)

# Define the index schema for product manuals
fields = [
    SimpleField(name="id", type=SearchFieldDataType.String, key=True),
    SearchableField(name="content", type=SearchFieldDataType.String, searchable=True),
    SimpleField(name="source", type=SearchFieldDataType.String, filterable=True),
    SearchableField(name="filename", type=SearchFieldDataType.String, searchable=True),
    SearchField(
        name="embedding",
        type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
        searchable=True,
        vector_search_dimensions=1536,
        vector_search_profile_name="myHnswProfile",
    ),
]

# Configure vector search
vector_search = VectorSearch(
    algorithms=[
        HnswAlgorithmConfiguration(
            name="myHnsw",
            parameters={
                "m": 4,
                "efConstruction": 400,
                "efSearch": 500,
                "metric": "cosine",
            }
        )
    ],
    profiles=[
        VectorSearchProfile(
            name="myHnswProfile",
            algorithm_configuration_name="myHnsw",
        )
    ],
)

# Create index definition
index = SearchIndex(
    name=index_name,
    fields=fields,
    vector_search=vector_search,
)

# Delete existing index if it exists
try:
    print(f"🗑️ Attempting to delete existing index '{index_name}'...")
    search_index_client.delete_index(index_name)
    print(f"✅ Deleted existing index")
except Exception as e:
    print(f"⚠️ Index doesn't exist or couldn't be deleted (this is normal on first run): {e}")

# Create new index
try:
    print(f"📝 Creating new index '{index_name}'...")
    search_index_client.create_index(index)
    print(f"✅ Index '{index_name}' created successfully")
except Exception as e:
    print(f"❌ Error creating index: {e}")
    raise
# Out:
# 🔍 Connecting to Azure Search at: https://apsearchfoundary123.search.windows.net/
# 🗑️ Attempting to delete existing index 'contoso-manuals-index'...
# ✅ Deleted existing index
# 📝 Creating new index 'contoso-manuals-index'...
# ✅ Index 'contoso-manuals-index' created successfully

# %%
# Load manual files and generate embeddings
print(f"\n📄 Loading manual files from {path_to_data}...")

# Initialize OpenAI client for embeddings
openai_client = AzureOpenAI(
    api_version="2024-12-01-preview",
    azure_endpoint=openai_endpoint,
    api_key=openai_key
)

# Load all markdown files
manual_dir = Path(path_to_data)
documents = []
doc_id = 0

if not manual_dir.exists():
    print(f"❌ Directory not found: {path_to_data}")
    raise FileNotFoundError(f"Manual directory not found: {path_to_data}")

markdown_files = list(manual_dir.glob("*.md"))
print(f"Found {len(markdown_files)} markdown files")

for md_file in markdown_files:
    try:
        print(f"  Processing {md_file.name}...", end=" ")
        
        # Read file content
        with open(md_file, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Generate embedding for the content
        response = openai_client.embeddings.create(
            input=content,
            model="text-embedding-ada-002"
        )
        embedding = response.data[0].embedding
        
        # Create document
        doc = {
            "id": str(doc_id),
            "content": content[:2000],  # Limit content size
            "source": "product_manual",
            "filename": md_file.name,
            "embedding": embedding,
        }
        documents.append(doc)
        doc_id += 1
        
        print("✅")
        
    except Exception as e:
        print(f"❌ Error: {e}")
        continue

print(f"\n✅ Prepared {len(documents)} documents for upload")

# Upload documents to Azure Search
if documents:
    try:
        print(f"📤 Uploading {len(documents)} documents to Azure Search...")
        results = search_client.upload_documents(documents)
        
        successful = sum(1 for r in results if r.succeeded)
        print(f"✅ Successfully uploaded {successful}/{len(documents)} documents")
        
    except Exception as e:
        print(f"❌ Error uploading documents: {e}")
        raise
else:
    print("⚠️ No documents to upload")
# Out:
# 📄 Loading manual files from ./manuals...
# Found 20 markdown files
#   Processing product_info_1.md... ✅
#   Processing product_info_10.md... ✅
#   Processing product_info_11.md... ✅
#   Processing product_info_12.md... ✅
#   Processing product_info_13.md... ✅
#   Processing product_info_14.md... ✅
#   Processing product_info_15.md... ✅
#   Processing product_info_16.md... ✅
#   Processing product_info_17.md... ✅
#   Processing product_info_18.md... ✅
#   Processing product_info_19.md... ✅
#   Processing product_info_2.md... ✅
#   Processing product_info_20.md... ✅
#   Processing product_info_3.md... ✅
#   Processing product_info_4.md... ✅
#   Processing product_info_5.md... ✅
#   Processing product_info_6.md... ✅
#   Processing product_info_7.md... ✅
#   Processing product_info_8.md... ✅
#   Processing product_info_9.md... ✅
#
# ✅ Prepared 20 documents for upload
# 📤 Uploading 20 documents to Azure Search...
# ✅ Successfully uploaded 20/20 documents

# %%
print("\n✅ Manual index creation complete!")
# Out:
# ✅ Manual index creation complete!

# %%
# Optional: Verify index was created
try:
    index_stats = search_index_client.get_index(index_name)
    print(f"\n📊 Index Statistics:")
    print(f"  Index Name: {index_stats.name}")
    print(f"  Number of Fields: {len(index_stats.fields)}")
    print(f"  Fields: {', '.join([f.name for f in index_stats.fields])}")
except Exception as e:
    print(f"Could not retrieve index stats: {e}")
# Out:
# 📊 Index Statistics:
#   Index Name: contoso-manuals-index
#   Number of Fields: 5
#   Fields: id, content, source, filename, embedding
